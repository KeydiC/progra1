# %%
print("707")
# Out:
# 707

# %%
print("Holis soy keydi, tengo", 18, " años y estudio ing en ciencias de la computacion")
# Out:
# Holis soy keydi, tengo 18  años y estudio ing en ciencias de la computacion

# %%
nombre = "Jax"
edad = 22
altura = 2.50
estudiante = True
print(type(nombre))
# Out:
# <class 'str'>

# %%
numeros = [1, 2, 4, 6]
nombres = ["jax", "pomni", "kinger"]
mixta = [14, "ksksks", 24, "uwu"]

print(nombres[0])
print(numeros[2])
# Out:
# jax
# 4

# %%
datos = ["keydi", 18, "blanco"]
print("Mi nombre es: ",datos[0],"mi edad es: ", datos[1], "mi color fav es: ", datos[2])
# Out:
# Mi nombre es:  keydi mi edad es:  18 mi color fav es:  blanco

# %%
print(f"Mi nombre es: {datos[0]}, mi edad es: {datos[1]},mi color fav es: {datos[2]}")

# %%
a=6
b=8
print(a+b, a-b, a*b, a/b, a**b, a%b)
# Out:
# 14 -2 48 0.75 1679616 6

# %%
nombre1 = input("como t llamas? ")
print("Hola"+ nombre1+ "bienvenido a la clase :3")
# Out:
# Hola  kiki bienvenido a la clase :3

# %%
edad1 = int(input("cuantos años tienes?"))
print("Tienes "+ str(edad1)+ " años")
# Out:
# Tienes 78 años

# %%
altu = float(input("cuantos mides en metros?"))
print("Mides "+ str(altu)+ " metros")
# Out:
# Mides 1.88 metros

# %%
name=input("Como te llamas?")
num1=float(input("dame un numero: "))
num2=float(input("dame otro numero: "))
operaciones = [num1+num2, num1-num2, num1*num2, num1/num2, num1**num2]

print(f"Hola {name} aqui estan los resultados de tus operaciones ^^ ")
print(f"La suma de {num1} y {num2} es: {operaciones[0]}")
print(f"La resta de {num1} y {num2} es: {operaciones[1]}")
print(f"La ultiplicacion de {num1} y {num2} es: {operaciones[2]}")
print(f"La division de {num1} y {num2} es: {operaciones[3]}")
print(f"{num1} elevado a la potencia de {num2} es: {operaciones[4]}")
# Out:
# Hola kiki aqui estan los resultados de tus operaciones ^^
# La suma de 5.0 y 6.0 es: 11.0
# La resta de 5.0 y 6.0 es: -1.0
# La ultiplicacion de 5.0 y 6.0 es: 30.0
# La division de 5.0 y 6.0 es: 0.8333333333333334
#  5.0 elevado a la potencia de 6.0 es: 15625.0
