# %%
class Coche():
    def __init__(self, mrc, mdl, an, col):
        self.marca=mrc
        self.model=mdl
        self.anio=an
        self.color=col
    def desc(self):
        print(f"Este coche es de color {self.color} de la marca {self.marca} y modelo {self.model} y del año {self.anio}")

# %%
lista = [
    Coche("Ford", "Mustang", "2020", "azul"),
    Coche("Toyota", "Corolla", "2019", "blanco"),
    Coche("Honda", "Civic", "2018", "negro"),
    Coche("Chevrolet", "Camaro", "2021", "rojo"),
    Coche("BMW", "Serie 3", "2017", "gris"),
    Coche("Audi", "A4", "2020", "plateado"),
    Coche("Mercedes-Benz", "Clase C", "2019", "negro"),
    Coche("Volkswagen", "Golf", "2018", "azul"),
    Coche("Nissan", "Sentra", "2021", "blanco"),
    Coche("Hyundai", "Elantra", "2020", "gris"),
    Coche("Kia", "Rio", "2017", "rojo"),
    Coche("Mazda", "Mazda3", "2019", "azul"),
    Coche("Subaru", "Impreza", "2018", "verde"),
    Coche("Tesla", "Model 3", "2021", "blanco"),
    Coche("Peugeot", "308", "2019", "gris"),
    Coche("Renault", "Megane", "2018", "rojo"),
    Coche("Citroen", "C4", "2020", "azul"),
    Coche("Fiat", "Punto", "2016", "negro"),
    Coche("Seat", "Leon", "2021", "blanco"),
    Coche("Skoda", "Octavia", "2019", "plateado"),
    Coche("Volvo", "S60", "2020", "negro"),
    Coche("Jaguar", "XE", "2018", "azul"),
    Coche("Land Rover", "Evoque", "2021", "gris"),
    Coche("Porsche", "911", "2017", "rojo"),
    Coche("Ferrari", "488", "2019", "rojo"),
    Coche("Lamborghini", "Huracan", "2020", "amarillo"),
    Coche("Mitsubishi", "Lancer", "2016", "blanco"),
    Coche("Suzuki", "Swift", "2018", "azul"),
    Coche("Dodge", "Charger", "2021", "negro"),
    Coche("Jeep", "Wrangler", "2020", "verde"),
    Coche("Chrysler", "300", "2019", "gris"),
    Coche("Alfa Romeo", "Giulia", "2020", "rojo"),
    Coche("Mini", "Cooper", "2018", "blanco"),
    Coche("Opel", "Astra", "2019", "azul"),
    Coche("Honda", "Accord", "2021", "negro"),
    Coche("Toyota", "Camry", "2020", "gris"),
    Coche("Ford", "Focus", "2018", "blanco"),
    Coche("Chevrolet", "Malibu", "2019", "plateado"),
    Coche("BMW", "X5", "2021", "negro"),
    Coche("Audi", "Q5", "2020", "azul"),
    Coche("Mercedes-Benz", "GLA", "2019", "blanco"),
    Coche("Volkswagen", "Passat", "2018", "gris"),
    Coche("Nissan", "Altima", "2020", "rojo"),
    Coche("Hyundai", "Tucson", "2021", "plateado"),
    Coche("Kia", "Sportage", "2019", "negro"),
    Coche("Mazda", "CX-5", "2020", "blanco"),
    Coche("Subaru", "Forester", "2021", "verde"),
    Coche("Tesla", "Model Y", "2022", "azul")
]

# %%
for a in lista:
    a.desc()
# Out:
# Este coche es de color azul de la marca Ford y modelo Mustang y del año 2020
# Este coche es de color blanco de la marca Toyota y modelo Corolla y del año 2019
# Este coche es de color negro de la marca Honda y modelo Civic y del año 2018
# Este coche es de color rojo de la marca Chevrolet y modelo Camaro y del año 2021
# Este coche es de color gris de la marca BMW y modelo Serie 3 y del año 2017
# Este coche es de color plateado de la marca Audi y modelo A4 y del año 2020
# Este coche es de color negro de la marca Mercedes-Benz y modelo Clase C y del año 2019
# Este coche es de color azul de la marca Volkswagen y modelo Golf y del año 2018
# Este coche es de color blanco de la marca Nissan y modelo Sentra y del año 2021
# Este coche es de color gris de la marca Hyundai y modelo Elantra y del año 2020
# Este coche es de color rojo de la marca Kia y modelo Rio y del año 2017
# Este coche es de color azul de la marca Mazda y modelo Mazda3 y del año 2019
# ...
