# %%
import pandas as pd
df=pd.read_csv("01 Harry Potter and the Sorcerers Stone.csv")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File c:\Users\Salon202\AppData\Local\Programs\Python\Python314\Lib\site-packages\numpy\_core\__init__.py:24
#      23 try:
# ---> 24     from . import multiarray
#      25 except ImportError as exc:
#
# File c:\Users\Salon202\AppData\Local\Programs\Python\Python314\Lib\site-packages\numpy\_core\multiarray.py:11
#       9 import functools
# ---> 11 from . import _multiarray_umath, overrides
#      12 from ._multiarray_umath import *  # noqa: F403
#
# ImportError: DLL load failed while importing _multiarray_umath: Una directiva de Control de aplicaciones bloqueó este archivo.
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# File c:\Users\Salon202\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\__init__.py:23
# ...
